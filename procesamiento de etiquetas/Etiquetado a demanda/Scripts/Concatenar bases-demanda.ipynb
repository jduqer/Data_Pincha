# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os

# %%
cols_usar = ['Evento','Categoria', 'Zona inicial','Zona Final','Accion','Jugada','coord.inicial','coord.final','Temporada','partido']

# %% [markdown]
# ## Temp 2 - 2022

# %% [markdown]
# ## Fecha 1 Gimnasia

# %%
dataGim = pd.read_excel("../Datos generados/reserva02-22-fecha1_gimnasia_situaciones.xlsx")
dataGim.head(10)
# Out:
#        Fecha etiquetado         name Session Start Session End     Evento  \
# 0 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 1 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 2 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 3 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 4 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50    a favor
# 5 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 6 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 7 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 8 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50  en contra
# 9 2022-06-07   Gimnasia  Situaciones      08:53:25    11:15:50    a favor
#
#    Tag Notes Tag Start   Tag End  Tag Duration (secs)  ... Jugada  \
# 0        NaN  00:34:09  00:34:11                 2000  ...      1
# ...

# %%
dataGim = dataGim[cols_usar]

# %% [markdown]
# ## Fecha 2 - Aldosivi

# %%
dataAld = pd.read_excel("../Datos generados/reserva02-22-fecha2_aldosivi_situaciones.xlsx")
dataAld.head(10)
# Out:
#        Fecha etiquetado      name Session Start Session End   Evento  \
# 0 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 1 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 2 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 3 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 4 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 5 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 6 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 7 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 8 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
# 9 2022-06-12   Aldosivi  Completo      19:27:18    21:36:36  a favor
#
#    Tag Notes Tag Start   Tag End  Tag Duration (secs)  ... Jugada  \
# 0        NaN  00:28:36  00:28:38                 2000  ...      1
# 1        NaN  00:28:44  00:28:46                 2000  ...      1
# ...

# %%
dataAld = dataAld[cols_usar]

# %% [markdown]
# ## Fecha 3 - Sarmiento

# %%
dataSar = pd.read_excel("../Datos generados/reserva02-22-fecha3_sarmiento_situaciones.xlsx")
dataSar.head(10)
# Out:
#        Fecha etiquetado         name Session Start Session End     Evento  \
# 0 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 1 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 2 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 3 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 4 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 5 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 6 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 7 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 8 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 9 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
#
#    Tag Notes Tag Start   Tag End  Tag Duration (secs)  ... Jugada  \
# 0        NaN  00:21:17  00:21:19                 2000  ...      1
# ...

# %%
dataSar = dataSar[cols_usar]

# %% [markdown]
# ## Fecha 4 - Independiente

# %%
dataInd = pd.read_excel("../Datos generados/reserva02-22-fecha4_independiente_situaciones.xlsx")
dataInd.head(10)
# Out:
#        Fecha etiquetado         name Session Start Session End     Evento  \
# 0 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 1 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 2 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 3 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 4 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10    a favor
# 5 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 6 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 7 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 8 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
# 9 2022-06-19  Sarmiento  Situaciones      15:25:20    17:40:10  en contra
#
#    Tag Notes Tag Start   Tag End  Tag Duration (secs)  ... Jugada  \
# 0        NaN  00:21:17  00:21:19                 2000  ...      1
# ...

# %%
dataInd = dataInd[cols_usar]

# %% [markdown]
# ## Fecha 5 - Newells

# %%
dataNew = pd.read_excel("../Datos generados/reserva02-22-fecha5_newells_situaciones.xlsx")
dataNew.head(10)
# Out:
#        Fecha etiquetado         name Session Start Session End     Evento  \
# 0 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 1 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 2 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 3 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 4 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 5 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 6 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 7 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 8 2022-06-25    Newells  Situaciones      23:21:12    01:36:02    a favor
# 9 2022-06-25    Newells  Situaciones      23:21:12    01:36:02  en contra
#
#    Tag Notes Tag Start   Tag End  Tag Duration (secs)  ... Jugada  \
# 0        NaN  00:29:53  00:29:55                 2000  ...      1
# ...

# %%
dataNew = dataNew[cols_usar]

# %% [markdown]
# ## Fecha 6 - Arsenal

# %%
dataArs = pd.read_excel("../Datos generados/reserva02-22-fecha6_arsenal_situaciones.xlsx")
dataArs.head(10)
# Out:
#        Fecha etiquetado         name Session Start Session End     Evento  \
# 0 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19  en contra
# 1 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19  en contra
# 2 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19    a favor
# 3 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19    a favor
# 4 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19    a favor
# 5 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19  en contra
# 6 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19  en contra
# 7 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19  en contra
# 8 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19    a favor
# 9 2022-07-02    Arsenal  Situaciones      15:34:01    17:36:19    a favor
#
#    Tag Notes Tag Start   Tag End  Tag Duration (secs)  ... Jugada  \
# 0        NaN  00:14:36  00:14:38                 2000  ...      1
# ...

# %%
dataArs = dataArs[cols_usar]

# %% [markdown]
# ## Fecha 7 - Central Cordoba

# %%
dataCor = pd.read_excel("../Datos generados/reserva02-22-fecha7_cco_situaciones.xlsx")
dataCor.head(10)
# Out:
#        Fecha       etiquetado         name Session Start Session End  \
# 0 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 1 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 2 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 3 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 4 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 5 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 6 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 7 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 8 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
# 9 2022-07-10  Central Cordoba  Situaciones      09:47:33    11:57:38
#
#       Evento  Tag Notes Tag Start   Tag End  Tag Duration (secs)  ... Jugada  \
# 0    a favor        NaN  00:10:55  00:10:57                 2000  ...      1
# ...

# %%
dataCor = dataCor[cols_usar]

# %% [markdown]
# ## Ahora unir los datas

# %%
df = pd.concat([dataGim,dataAld,dataSar,dataInd,dataNew,dataArs,dataCor]).reset_index(drop=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Evento         290 non-null    object
#  1   Categoria      290 non-null    object
#  2   Zona inicial   290 non-null    float64
#  3   Zona Final     290 non-null    float64
#  4   Accion         290 non-null    object
#  5   Jugada         290 non-null    int64
#  6   coord.inicial  290 non-null    object
#  7   coord.final    290 non-null    object
#  8   Temporada      290 non-null    object
#  9   partido        290 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 22.8+ KB

# %%
df.partido.value_counts()
# Out:
# Sarmiento          52
# Independiente      52
# Gimnasia           42
# Newells            41
# Central Cordoba    39
# Aldosivi           38
# Arsenal            26
# Name: partido, dtype: int64

# %%
df.to_excel("../Datos generados/Situaciones_total.xlsx",index=False)
